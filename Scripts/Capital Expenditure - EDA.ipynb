# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
source_folder = "../datasets/"
file1 = "greater-hyderabad-municipal-corporation-capital-expenditure.csv"
file2 = "greater-hyderabad-municipal-corporation-revenue-expenditure.csv"
dataset1 = source_folder + file1
dataset2 = source_folder + file2

# %%
capital_df = pd.read_csv(dataset1)
revenue_df = pd.read_csv(dataset2)

# %%
selected_year ="2016-17  Budget Estimates"

# %%
capital_df.columns
# Out:
# Index([u'Function', u'Function code', u'Major Account Head Description',
#        u'Major Account Code', u'Detailed Account Code Description',
#        u'Detailed Account Code', u'2012-13 Actuals',
#        u' 2013-14 Budget Estimates', u'2013-14 Revised Estimates',
#        u'2013-14 Actuals', u' 2014-15 Budget Estimates',
#        u'2014-15 Revised Estimates', u'2014-15 Actuals',
#        u'2015-16 Budget Estimates', u'2015-16 Revised Estimates',
#        u'2016-17  Budget Estimates', u'record_type'],
#       dtype='object')

# %%
capital_df["Function"].unique()
# Out:
# array(['General Administration', 'Total for General Administration (0201)',
#        'Information Technology', 'Total for Information Technology (0203)',
#        'City and Town Planning', 'Total for City and Town Planning (1100)',
#        'Street Lighting', 'Total for Street Lighting (2400)',
#        'Transportation Planning',
#        'Total for Transportation Planning (2602)', 'Public Works-General',
#        'Total for Public Works-General (2801)', 'Public Health',
#        'Total for Public Health (3100)', 'MRTS',
#        'Total for Mass Rapid Transport System (4201)', 'Water Supply',
#        'Total for Water Supply (5100)', 'Play Grounds ',
#        'Total for Play Grounds (6200)', 'Urban Forestry',
#        'Total for Urban Forestry (6400)', 'Horticulture',
#        'Total for Horticulture (6401)', 'Urban Poverty Alleviation',
#        'Total for Urban Poverty Alleviation (7800)', 'Advertisement ',
#        'Total for Advertisement (9300)', nan], dtype=object)

# %%
capital_df[capital_df["record_type"] == "record"].sort_values(by=selected_year, ascending=False).head(15)[['Function','Major Account Head Description', 'Detailed Account Code Description']]
# Out:
#                      Function Major Account Head Description  \
# 26       Public Works-General              Roads & Pavements
# 55                       MRTS              Land Improvements
# 81  Urban Poverty Alleviation              Roads & Pavements
# 78  Urban Poverty Alleviation                        Housing
# 27       Public Works-General              Roads & Pavements
# 33       Public Works-General        Water Supply & Sewerage
# 24       Public Works-General          Multi Model Transport
# 30       Public Works-General           Storm Water Drainage
# 31       Public Works-General           Storm Water Drainage
# 16       Public Works-General                      Buildings
# 47              Public Health              Land Improvements
# 71               Horticulture              Land Improvements
# 65             Urban Forestry              Land Improvements
# 28       Public Works-General              Roads & Pavements
# ...

# %%
capital_df[capital_df["Function"] == "Public Works-General"].sort_values(by=selected_year, ascending=False)[['Major Account Head Description',"Detailed Account Code Description", selected_year]]
# Out:
#    Major Account Head Description  \
# 26              Roads & Pavements
# 27              Roads & Pavements
# 33        Water Supply & Sewerage
# 24          Multi Model Transport
# 30           Storm Water Drainage
# 31           Storm Water Drainage
# 16                      Buildings
# 28              Roads & Pavements
# 34        Water Supply & Sewerage
# 32        Water Supply & Sewerage
# 17    Bridges, Flyovers & Subways
# 25              Land Improvements
# 23                      Buildings
# 21              Land Improvements
# 36              Land Improvements
# 18    Bridges, Flyovers & Subways
# 22              Land Improvements
# 15                      Buildings
# 20              Land Improvements
# 29              Roads & Pavements
# 35              Land Improvements
# 19    Bridges, Flyovers & Subways
# 38          Machinery & Equipment
# 40         Furniture and Fixtures
# 41         Furniture and Fixtures
# 37              Land Improvements
# ...

# %%
capital_df[capital_df["Function"] == "Public Health"].sort_values(by=selected_year, ascending=False)[['Major Account Head Description',"Detailed Account Code Description", selected_year]]
# Out:
#    Major Account Head Description  \
# 47              Land Improvements
# 49                      Buildings
# 51                       Vehicles
# 50                      Buildings
# 48                      Buildings
# 53          Machinery & Equipment
# 52                       Vehicles
#
#                     Detailed Account Code Description  \
# 47  Construction of Garbage Dumping Yards & Transf...
# 49                          Burial Grounds/Crematoria
# 51                     Purchase of New Heavy Vehicles
# 50                  Modernisation of Slaughter Houses
# 48                          Public Latrines & Urinals
# 53           Dumber Bins/Garbage Dust and Litter Bins
# 52                     Purchase of New Light Vehicles
#
#     2016-17  Budget Estimates
# 47                     7810.0
# 49                     3327.4
# 51                     2100.0
# 50                     2000.0
# 48                      813.6
# 53                      362.0
# ...

# %%
capital_df[capital_df["Function"] == "Advertisement "].sort_values(by=selected_year, ascending=False)[['Major Account Head Description',"Detailed Account Code Description", selected_year]]
# Out:
#    Major Account Head Description Detailed Account Code Description  \
# 91          Multi Model Transport   Erection of Modern Bus Shelters
#
#     2016-17  Budget Estimates
# 91                       1903

# %%
capital_df[capital_df["Function"] == "Transportation Planning"].sort_values(by=selected_year, ascending=False)[['Major Account Head Description',"Detailed Account Code Description", selected_year]]
# Out:
#    Major Account Head Description  \
# 12              Roads & Pavements
# 13          Multi Model Transport
# 11              Land Improvements
#
#                     Detailed Account Code Description  \
# 12                              Junction Improvements
# 13                          Traffic Signals & Signage
# 11  Construction & Improvement of Traffic Islands ...
#
#     2016-17  Budget Estimates
# 12                       1100
# 13                        650
# 11                        124

# %%
capital_df[capital_df["Function"] == "Information Technology"].sort_values(by=selected_year, ascending=False)[['Major Account Head Description',"Detailed Account Code Description", selected_year]]
# Out:
#   Major Account Head Description  \
# 3          Machinery & Equipment
# 4          Machinery & Equipment
#
#                    Detailed Account Code Description  \
# 3  Purchase and Installation of Computers, Server...
# 4                        ERP Licenses/Implementation
#
#    2016-17  Budget Estimates
# 3                       1615
# 4                        500
